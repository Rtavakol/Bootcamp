# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
sklearn.__version__
# Out:
# '0.22.1'

# %%
# Load data
df = pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x = df.iloc[:, : -1]
y = df.iloc[:, 1]

# %%
# Split data into training and test datasets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 11)

# %%
# Linear regression model
LR = LinearRegression()

# Fit the model
LR.fit(x_train, y_train)

# Coefficient and intercept
print(LR.coef_, LR.intercept_)
# Out:
# [9435.13971011] 25839.34946109404

# %%
fit_line = [i * LR.coef_ + LR.intercept_ for i in x_test['YearsExperience']]
y_predic = LR.predict(x_test)

# %%
# %matplotlib notebook
plt.scatter(x_test, y_test, label = 'test data')
plt.scatter(x_test, y_predic, label = 'y_predict')
plt.plot(x_test['YearsExperience'], fit_line, label = 'fit line')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
